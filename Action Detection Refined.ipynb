# %% [markdown]
# # 1. Import and Install Dependencies

# %%
# !pip install tensorflow==2.9.1 tensorflow-gpu==2.9.1 opencv-python mediapipe sklearn matplotlib
# Out:
# Requirement already satisfied: tensorflow==2.9.1 in s:\anaconda\lib\site-packages (2.9.1)
# Requirement already satisfied: tensorflow-gpu==2.9.1 in s:\anaconda\lib\site-packages (2.9.1)
# Requirement already satisfied: opencv-python in s:\anaconda\lib\site-packages (4.6.0.66)
# Requirement already satisfied: mediapipe in s:\anaconda\lib\site-packages (0.8.10.1)
# Requirement already satisfied: sklearn in s:\anaconda\lib\site-packages (0.0)
# Requirement already satisfied: matplotlib in s:\anaconda\lib\site-packages (3.4.3)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in s:\anaconda\lib\site-packages (from tensorflow==2.9.1) (3.19.4)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in s:\anaconda\lib\site-packages (from tensorflow==2.9.1) (0.4.0)
# Requirement already satisfied: setuptools in s:\anaconda\lib\site-packages (from tensorflow==2.9.1) (58.0.4)
# Requirement already satisfied: keras<2.10.0,>=2.9.0rc0 in s:\anaconda\lib\site-packages (from tensorflow==2.9.1) (2.9.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in s:\anaconda\lib\site-packages (from tensorflow==2.9.1) (0.26.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in s:\anaconda\lib\site-packages (from tensorflow==2.9.1) (3.3.0)
# Requirement already satisfied: flatbuffers<2,>=1.12 in s:\anaconda\lib\site-packages (from tensorflow==2.9.1) (1.12)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in s:\anaconda\lib\site-packages (from tensorflow==2.9.1) (1.1.2)
# Requirement already satisfied: h5py>=2.9.0 in s:\anaconda\lib\site-packages (from tensorflow==2.9.1) (3.2.1)
# Requirement already satisfied: google-pasta>=0.1.1 in s:\anaconda\lib\site-packages (from tensorflow==2.9.1) (0.2.0)
# Requirement already satisfied: wrapt>=1.11.0 in s:\anaconda\lib\site-packages (from tensorflow==2.9.1) (1.12.1)
# Requirement already satisfied: libclang>=13.0.0 in s:\anaconda\lib\site-packages (from tensorflow==2.9.1) (14.0.6)
# Requirement already satisfied: typing-extensions>=3.6.6 in s:\anaconda\lib\site-packages (from tensorflow==2.9.1) (3.10.0.2)
# Requirement already satisfied: numpy>=1.20 in s:\anaconda\lib\site-packages (from tensorflow==2.9.1) (1.22.4)
# Requirement already satisfied: packaging in s:\anaconda\lib\site-packages (from tensorflow==2.9.1) (21.0)
# Requirement already satisfied: termcolor>=1.1.0 in s:\anaconda\lib\site-packages (from tensorflow==2.9.1) (1.1.0)
# Requirement already satisfied: tensorboard<2.10,>=2.9 in s:\anaconda\lib\site-packages (from tensorflow==2.9.1) (2.9.1)
# Requirement already satisfied: astunparse>=1.6.0 in s:\anaconda\lib\site-packages (from tensorflow==2.9.1) (1.6.3)
# Requirement already satisfied: six>=1.12.0 in s:\anaconda\lib\site-packages (from tensorflow==2.9.1) (1.15.0)
# Requirement already satisfied: tensorflow-estimator<2.10.0,>=2.9.0rc0 in s:\anaconda\lib\site-packages (from tensorflow==2.9.1) (2.9.0)
# Requirement already satisfied: absl-py>=1.0.0 in s:\anaconda\lib\site-packages (from tensorflow==2.9.1) (1.2.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in s:\anaconda\lib\site-packages (from tensorflow==2.9.1) (1.47.0)
# Requirement already satisfied: attrs>=19.1.0 in s:\anaconda\lib\site-packages (from mediapipe) (21.2.0)
# Requirement already satisfied: opencv-contrib-python in s:\anaconda\lib\site-packages (from mediapipe) (4.6.0.66)
# Requirement already satisfied: scikit-learn in s:\anaconda\lib\site-packages (from sklearn) (0.24.2)
# Requirement already satisfied: pillow>=6.2.0 in s:\anaconda\lib\site-packages (from matplotlib) (8.4.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in s:\anaconda\lib\site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: pyparsing>=2.2.1 in s:\anaconda\lib\site-packages (from matplotlib) (3.0.4)
# Requirement already satisfied: python-dateutil>=2.7 in s:\anaconda\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in s:\anaconda\lib\site-packages (from matplotlib) (0.10.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in s:\anaconda\lib\site-packages (from astunparse>=1.6.0->tensorflow==2.9.1) (0.37.0)
# Requirement already satisfied: werkzeug>=1.0.1 in s:\anaconda\lib\site-packages (from tensorboard<2.10,>=2.9->tensorflow==2.9.1) (2.0.2)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in s:\anaconda\lib\site-packages (from tensorboard<2.10,>=2.9->tensorflow==2.9.1) (0.4.6)
# Requirement already satisfied: markdown>=2.6.8 in s:\anaconda\lib\site-packages (from tensorboard<2.10,>=2.9->tensorflow==2.9.1) (3.4.1)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in s:\anaconda\lib\site-packages (from tensorboard<2.10,>=2.9->tensorflow==2.9.1) (0.6.1)
# Requirement already satisfied: requests<3,>=2.21.0 in s:\anaconda\lib\site-packages (from tensorboard<2.10,>=2.9->tensorflow==2.9.1) (2.26.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in s:\anaconda\lib\site-packages (from tensorboard<2.10,>=2.9->tensorflow==2.9.1) (2.11.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in s:\anaconda\lib\site-packages (from tensorboard<2.10,>=2.9->tensorflow==2.9.1) (1.8.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in s:\anaconda\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow==2.9.1) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in s:\anaconda\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow==2.9.1) (4.9)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in s:\anaconda\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow==2.9.1) (5.2.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in s:\anaconda\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.10,>=2.9->tensorflow==2.9.1) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in s:\anaconda\lib\site-packages (from markdown>=2.6.8->tensorboard<2.10,>=2.9->tensorflow==2.9.1) (4.8.1)
# Requirement already satisfied: zipp>=0.5 in s:\anaconda\lib\site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.10,>=2.9->tensorflow==2.9.1) (3.6.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in s:\anaconda\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow==2.9.1) (0.4.8)
# Requirement already satisfied: idna<4,>=2.5 in s:\anaconda\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow==2.9.1) (3.2)
# Requirement already satisfied: certifi>=2017.4.17 in s:\anaconda\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow==2.9.1) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in s:\anaconda\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow==2.9.1) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in s:\anaconda\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow==2.9.1) (1.26.7)
# Requirement already satisfied: oauthlib>=3.0.0 in s:\anaconda\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.10,>=2.9->tensorflow==2.9.1) (3.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in s:\anaconda\lib\site-packages (from scikit-learn->sklearn) (2.2.0)
# Requirement already satisfied: scipy>=0.19.1 in s:\anaconda\lib\site-packages (from scikit-learn->sklearn) (1.7.1)
# Requirement already satisfied: joblib>=0.11 in s:\anaconda\lib\site-packages (from scikit-learn->sklearn) (1.1.0)

# %%
import cv2
import numpy as np
import os
from matplotlib import pyplot as plt
import time
import mediapipe as mp

# %% [markdown]
# # 2. Keypoints using MP Holistic

# %%
mp_holistic = mp.solutions.holistic # Holistic model
mp_drawing = mp.solutions.drawing_utils # Drawing utilities

# %%
def mediapipe_detection(image, model):
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB) # COLOR CONVERSION BGR 2 RGB
    image.flags.writeable = False                  # Image is no longer writeable
    results = model.process(image)                 # Make prediction
    image.flags.writeable = True                   # Image is now writeable 
    image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR) # COLOR COVERSION RGB 2 BGR
    return image, results

# %%
def draw_landmarks(image, results):
    mp_drawing.draw_landmarks(image, results.face_landmarks, mp_holistic.FACEMESH_TESSELATION) # Draw face connections
    mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS) # Draw pose connections
    mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS) # Draw left hand connections
    mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS) # Draw right hand connections

# %%
def draw_styled_landmarks(image, results):
    # Draw face connections
    mp_drawing.draw_landmarks(image, results.face_landmarks, mp_holistic.FACEMESH_TESSELATION, 
                             mp_drawing.DrawingSpec(color=(80,110,10), thickness=1, circle_radius=1), 
                             mp_drawing.DrawingSpec(color=(80,256,121), thickness=1, circle_radius=1)
                             ) 
    # Draw pose connections
    mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS,
                             mp_drawing.DrawingSpec(color=(80,22,10), thickness=2, circle_radius=4), 
                             mp_drawing.DrawingSpec(color=(80,44,121), thickness=2, circle_radius=2)
                             ) 
    # Draw left hand connections
    mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                             mp_drawing.DrawingSpec(color=(121,22,76), thickness=2, circle_radius=4), 
                             mp_drawing.DrawingSpec(color=(121,44,250), thickness=2, circle_radius=2)
                             ) 
    # Draw right hand connections  
    mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                             mp_drawing.DrawingSpec(color=(245,117,66), thickness=2, circle_radius=4), 
                             mp_drawing.DrawingSpec(color=(245,66,230), thickness=2, circle_radius=2)
                             )

# %%
cap = cv2.VideoCapture(0)
# Set mediapipe model 
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    while cap.isOpened():

        # Read feed
        ret, frame = cap.read()

        # Make detections
        image, results = mediapipe_detection(frame, holistic)
        print(results)
        
        # Draw landmarks
        draw_styled_landmarks(image, results)

        # Show to screen
        cv2.imshow('OpenCV Feed', image)

        # Break gracefully
        if cv2.waitKey(10) & 0xFF == ord('q'):
            break
    cap.release()
    cv2.destroyAllWindows()
# Out:
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>

# %%
draw_landmarks(frame, results)

# %%
plt.imshow(cv2.cvtColor(frame, cv2.COLOR_BGR2RGB))

# %% [markdown]
# # 3. Extract Keypoint Values

# %%
len(results.left_hand_landmarks.landmark)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_23272/1858948676.py in <module>
# ----> 1 len(results.left_hand_landmarks.landmark)
#
# AttributeError: 'NoneType' object has no attribute 'landmark'

# %%
len(results.pose_landmarks.landmark)
# Out:
# 33

# %%
pose = []
for res in results.pose_landmarks.landmark:
    test = np.array([res.x, res.y, res.z, res.visibility])
    pose.append(test)

# %%
pose = np.array([[res.x, res.y, res.z, res.visibility] for res in results.pose_landmarks.landmark]).flatten() if results.pose_landmarks else np.zeros(132)
face = np.array([[res.x, res.y, res.z] for res in results.face_landmarks.landmark]).flatten() if results.face_landmarks else np.zeros(1404)
lh = np.array([[res.x, res.y, res.z] for res in results.left_hand_landmarks.landmark]).flatten() if results.left_hand_landmarks else np.zeros(21*3)
rh = np.array([[res.x, res.y, res.z] for res in results.right_hand_landmarks.landmark]).flatten() if results.right_hand_landmarks else np.zeros(21*3)

# %%
def extract_keypoints(results):
    pose = np.array([[res.x, res.y, res.z, res.visibility] for res in results.pose_landmarks.landmark]).flatten() if results.pose_landmarks else np.zeros(33*4)
    face = np.array([[res.x, res.y, res.z] for res in results.face_landmarks.landmark]).flatten() if results.face_landmarks else np.zeros(468*3)
    lh = np.array([[res.x, res.y, res.z] for res in results.left_hand_landmarks.landmark]).flatten() if results.left_hand_landmarks else np.zeros(21*3)
    rh = np.array([[res.x, res.y, res.z] for res in results.right_hand_landmarks.landmark]).flatten() if results.right_hand_landmarks else np.zeros(21*3)
    return np.concatenate([pose, face, lh, rh])

# %%
result_test = extract_keypoints(results)

# %%
result_test
# Out:
# array([ 0.59226817,  0.51626867, -0.80300438, ...,  0.22168005,
#         0.19476885, -0.0348968 ])

# %%
np.save('0', result_test)

# %%
np.load('0.npy')
# Out:
# array([ 0.59226817,  0.51626867, -0.80300438, ...,  0.22168005,
#         0.19476885, -0.0348968 ])

# %% [markdown]
# # 4. Setup Folders for Collection

# %%
# Path for exported data, numpy arrays
DATA_PATH = os.path.join('MP_Data') 

# Actions that we try to detect
actions = np.array(['hello', 'thanks', 'iloveyou', 'Yes', 'No'])

# Thirty videos worth of data
no_sequences = 30

# Videos are going to be 30 frames in length
sequence_length = 30

# Folder start
start_folder = 30

# %%
for action in actions: 
#     dirmax = np.max(np.array(os.listdir(os.path.join(DATA_PATH, action))).astype(int))
    for sequence in range(no_sequences):
        try: 
            os.makedirs(os.path.join(DATA_PATH, action, str(sequence)))
        except:
            pass

# %% [markdown]
# # 5. Collect Keypoint Values for Training and Testing

# %%
cap = cv2.VideoCapture(1)
# Set mediapipe model 
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    
    # NEW LOOP
    # Loop through actions
    for action in actions:
        # Loop through sequences aka videos
        for sequence in range(no_sequences):
            # Loop through video length aka sequence length
            for frame_num in range(sequence_length):

                # Read feed
                ret, frame = cap.read()

                # Make detections
                image, results = mediapipe_detection(frame, holistic)
#                 print(results)

                # Draw landmarks
                draw_styled_landmarks(image, results)
                
                # NEW Apply wait logic
                if frame_num == 0: 
                    cv2.putText(image, 'STARTING COLLECTION', (120,200), 
                               cv2.FONT_HERSHEY_SIMPLEX, 1, (0,255, 0), 4, cv2.LINE_AA)
                    cv2.putText(image, 'Collecting frames for {} Video Number {}'.format(action, sequence), (15,12), 
                               cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 255), 1, cv2.LINE_AA)
                    # Show to screen
                    cv2.imshow('OpenCV Feed', image)
                    cv2.waitKey(2000)
                else: 
                    cv2.putText(image, 'Collecting frames for {} Video Number {}'.format(action, sequence), (15,12), 
                               cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 255), 1, cv2.LINE_AA)
                    # Show to screen
                    cv2.imshow('OpenCV Feed', image)
                
                # NEW Export keypoints
                keypoints = extract_keypoints(results)
                npy_path = os.path.join(DATA_PATH, action, str(sequence), str(frame_num))
                np.save(npy_path, keypoints)

                # Break gracefully
                if cv2.waitKey(10) & 0xFF == ord('q'):
                    break
                    
    cap.release()
    cv2.destroyAllWindows()

# %%
cap.release()
cv2.destroyAllWindows()

# %% [markdown]
# # 6. Preprocess Data and Create Labels and Features

# %%
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical

# %%
label_map = {label:num for num, label in enumerate(actions)}

# %%
label_map
# Out:
# {'hello': 0, 'thanks': 1, 'iloveyou': 2, 'Yes': 3, 'No': 4}

# %%
sequences, labels = [], []
for action in actions:
    for sequence in np.array(os.listdir(os.path.join(DATA_PATH, action))).astype(int):
        window = []
        for frame_num in range(sequence_length):
            res = np.load(os.path.join(DATA_PATH, action, str(sequence), "{}.npy".format(frame_num)))
            window.append(res)
        sequences.append(window)
        labels.append(label_map[action])

# %%
np.array(sequences).shape
# Out:
# (150, 30, 1662)

# %%
np.array(labels).shape
# Out:
# (150,)

# %%
X = np.array(sequences)

# %%
X.shape
# Out:
# (150, 30, 1662)

# %%
y = to_categorical(labels).astype(int)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.05)

# %%
y_test.shape
# Out:
# (8, 5)

# %% [markdown]
# # 7. Build and Train LSTM Neural Network

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.keras.callbacks import TensorBoard

# %%
log_dir = os.path.join('Logs')
tb_callback = TensorBoard(log_dir=log_dir)

# %%
model = Sequential()
model.add(LSTM(64, return_sequences=True, activation='relu', input_shape=(30,1662)))
model.add(LSTM(128, return_sequences=True, activation='relu'))
model.add(LSTM(64, return_sequences=False, activation='relu'))
model.add(Dense(64, activation='relu'))
model.add(Dense(32, activation='relu'))
model.add(Dense(actions.shape[0], activation='softmax'))

# %%
model.compile(optimizer='Adam', loss='categorical_crossentropy', metrics=['categorical_accuracy'])

# %%
model.fit(X_train, y_train, epochs=1500, callbacks=[tb_callback])
# Out:
# Epoch 1/1500
# 5/5 [==============================] - 6s 143ms/step - loss: 1.8259 - categorical_accuracy: 0.2394
# Epoch 2/1500
# 5/5 [==============================] - 1s 119ms/step - loss: 1.7444 - categorical_accuracy: 0.2606
# Epoch 3/1500
# 5/5 [==============================] - 1s 125ms/step - loss: 1.9784 - categorical_accuracy: 0.2394
# Epoch 4/1500
# 5/5 [==============================] - 1s 119ms/step - loss: 1.6591 - categorical_accuracy: 0.2606
# Epoch 5/1500
# 5/5 [==============================] - 1s 119ms/step - loss: 1.6127 - categorical_accuracy: 0.3239
# Epoch 6/1500
# 5/5 [==============================] - 1s 119ms/step - loss: 1.8458 - categorical_accuracy: 0.2183
# Epoch 7/1500
# 5/5 [==============================] - 1s 116ms/step - loss: 1.6369 - categorical_accuracy: 0.2465
# Epoch 8/1500
# 5/5 [==============================] - 1s 126ms/step - loss: 2.2001 - categorical_accuracy: 0.2113
# Epoch 9/1500
# 5/5 [==============================] - 1s 114ms/step - loss: 1.6235 - categorical_accuracy: 0.2817
# Epoch 10/1500
# 5/5 [==============================] - 1s 126ms/step - loss: 1.5537 - categorical_accuracy: 0.3099
# Epoch 11/1500
# 5/5 [==============================] - 1s 133ms/step - loss: 1.5016 - categorical_accuracy: 0.3169
# Epoch 12/1500
# 5/5 [==============================] - 1s 127ms/step - loss: 1.4321 - categorical_accuracy: 0.3592
# Epoch 13/1500
# 5/5 [==============================] - 1s 129ms/step - loss: 1.5481 - categorical_accuracy: 0.3521
# Epoch 14/1500
# 5/5 [==============================] - 1s 122ms/step - loss: 1.4033 - categorical_accuracy: 0.3732
# Epoch 15/1500
# 5/5 [==============================] - 1s 127ms/step - loss: 1.4401 - categorical_accuracy: 0.3662
# Epoch 16/1500
# 5/5 [==============================] - 1s 126ms/step - loss: 2.7090 - categorical_accuracy: 0.2465
# Epoch 17/1500
# 5/5 [==============================] - 1s 118ms/step - loss: 1.5948 - categorical_accuracy: 0.2746
# Epoch 18/1500
# 5/5 [==============================] - 1s 125ms/step - loss: 1.6412 - categorical_accuracy: 0.1972
# Epoch 19/1500
# 5/5 [==============================] - 1s 130ms/step - loss: 1.6210 - categorical_accuracy: 0.2183
# Epoch 20/1500
# 5/5 [==============================] - 1s 130ms/step - loss: 1.5976 - categorical_accuracy: 0.2183
# Epoch 21/1500
# 5/5 [==============================] - 1s 131ms/step - loss: 1.5876 - categorical_accuracy: 0.2746
# Epoch 22/1500
# 5/5 [==============================] - 1s 126ms/step - loss: 1.5684 - categorical_accuracy: 0.2676
# Epoch 23/1500
# 5/5 [==============================] - 1s 126ms/step - loss: 1.5342 - categorical_accuracy: 0.2887
# Epoch 24/1500
# 5/5 [==============================] - 1s 128ms/step - loss: 1.4477 - categorical_accuracy: 0.3310
# Epoch 25/1500
# 5/5 [==============================] - 1s 128ms/step - loss: 2.8078 - categorical_accuracy: 0.1901
# Epoch 26/1500
# 5/5 [==============================] - 1s 127ms/step - loss: 1.6007 - categorical_accuracy: 0.2113
# Epoch 27/1500
# 5/5 [==============================] - 1s 128ms/step - loss: 1.5997 - categorical_accuracy: 0.2042
# Epoch 28/1500
# 5/5 [==============================] - 1s 129ms/step - loss: 1.5972 - categorical_accuracy: 0.1831
# Epoch 29/1500
# 5/5 [==============================] - 1s 124ms/step - loss: 1.5978 - categorical_accuracy: 0.2183
# Epoch 30/1500
# 5/5 [==============================] - 1s 125ms/step - loss: 1.5967 - categorical_accuracy: 0.2113
# Epoch 31/1500
# 5/5 [==============================] - 1s 126ms/step - loss: 1.5958 - categorical_accuracy: 0.2113
# Epoch 32/1500
# 5/5 [==============================] - 1s 125ms/step - loss: 1.5951 - categorical_accuracy: 0.2113
# Epoch 33/1500
# 5/5 [==============================] - 1s 127ms/step - loss: 1.5946 - categorical_accuracy: 0.2113
# Epoch 34/1500
# 5/5 [==============================] - 1s 132ms/step - loss: 1.5936 - categorical_accuracy: 0.2113
# Epoch 35/1500
# 5/5 [==============================] - 1s 136ms/step - loss: 1.6863 - categorical_accuracy: 0.2042
# Epoch 36/1500
# 5/5 [==============================] - 1s 125ms/step - loss: 1.5943 - categorical_accuracy: 0.2465
# Epoch 37/1500
# 5/5 [==============================] - 1s 131ms/step - loss: 1.5926 - categorical_accuracy: 0.2887
# Epoch 38/1500
# 5/5 [==============================] - 1s 136ms/step - loss: 1.5920 - categorical_accuracy: 0.2887
# Epoch 39/1500
# 5/5 [==============================] - 1s 127ms/step - loss: 1.5887 - categorical_accuracy: 0.2324
# Epoch 40/1500
# 5/5 [==============================] - 1s 132ms/step - loss: 1.5842 - categorical_accuracy: 0.2183
# Epoch 41/1500
# 5/5 [==============================] - 1s 133ms/step - loss: 1.5851 - categorical_accuracy: 0.2183
# Epoch 42/1500
# 5/5 [==============================] - 1s 129ms/step - loss: 1.5827 - categorical_accuracy: 0.2958
# Epoch 43/1500
# 5/5 [==============================] - 1s 128ms/step - loss: 1.5800 - categorical_accuracy: 0.3662
# Epoch 44/1500
# 5/5 [==============================] - 1s 127ms/step - loss: 1.5734 - categorical_accuracy: 0.3310
# Epoch 45/1500
# 5/5 [==============================] - 1s 128ms/step - loss: 1.5636 - categorical_accuracy: 0.3732
# Epoch 46/1500
# 5/5 [==============================] - 1s 165ms/step - loss: 1.5428 - categorical_accuracy: 0.3521
# Epoch 47/1500
# 5/5 [==============================] - 1s 133ms/step - loss: 1.5053 - categorical_accuracy: 0.3028
# Epoch 48/1500
# 5/5 [==============================] - 1s 129ms/step - loss: 1.5016 - categorical_accuracy: 0.3592
# Epoch 49/1500
# 5/5 [==============================] - 1s 131ms/step - loss: 1.5117 - categorical_accuracy: 0.3662
# Epoch 50/1500
# 5/5 [==============================] - 1s 129ms/step - loss: 1.4661 - categorical_accuracy: 0.3169
# Epoch 51/1500
# 5/5 [==============================] - 1s 129ms/step - loss: 1.3426 - categorical_accuracy: 0.4718
# Epoch 52/1500
# 5/5 [==============================] - 1s 133ms/step - loss: 1.3126 - categorical_accuracy: 0.4296
# Epoch 53/1500
# 5/5 [==============================] - 1s 128ms/step - loss: 1.2460 - categorical_accuracy: 0.4577
# Epoch 54/1500
# 5/5 [==============================] - 1s 135ms/step - loss: 1.2786 - categorical_accuracy: 0.3662
# Epoch 55/1500
# 5/5 [==============================] - 1s 130ms/step - loss: 1.2256 - categorical_accuracy: 0.4577
# Epoch 56/1500
# 5/5 [==============================] - 1s 132ms/step - loss: 1.7005 - categorical_accuracy: 0.3521
# Epoch 57/1500
# 5/5 [==============================] - 1s 130ms/step - loss: 1.5736 - categorical_accuracy: 0.2042
# Epoch 58/1500
# 5/5 [==============================] - 1s 146ms/step - loss: 1.5995 - categorical_accuracy: 0.2113
# Epoch 59/1500
# 5/5 [==============================] - 1s 161ms/step - loss: 1.5812 - categorical_accuracy: 0.1901
# Epoch 60/1500
# 5/5 [==============================] - 1s 156ms/step - loss: 1.5617 - categorical_accuracy: 0.2183
# Epoch 61/1500
# 5/5 [==============================] - 1s 135ms/step - loss: 1.5285 - categorical_accuracy: 0.3169
# Epoch 62/1500
# 5/5 [==============================] - 1s 132ms/step - loss: 1.4733 - categorical_accuracy: 0.3451
# Epoch 63/1500
# 5/5 [==============================] - 1s 135ms/step - loss: 1.4537 - categorical_accuracy: 0.3310
# Epoch 64/1500
# 5/5 [==============================] - 1s 145ms/step - loss: 1.4054 - categorical_accuracy: 0.3873
# Epoch 65/1500
# 5/5 [==============================] - 1s 136ms/step - loss: 1.4611 - categorical_accuracy: 0.3451
# Epoch 66/1500
# 5/5 [==============================] - 1s 147ms/step - loss: 1.4829 - categorical_accuracy: 0.2817
# Epoch 67/1500
# 5/5 [==============================] - 1s 129ms/step - loss: 1.6740 - categorical_accuracy: 0.1549
# Epoch 68/1500
# 5/5 [==============================] - 1s 143ms/step - loss: 1.4658 - categorical_accuracy: 0.3310
# Epoch 69/1500
# 5/5 [==============================] - 1s 127ms/step - loss: 1.4394 - categorical_accuracy: 0.3310
# Epoch 70/1500
# 5/5 [==============================] - 1s 131ms/step - loss: 1.4498 - categorical_accuracy: 0.2183
# Epoch 71/1500
# 5/5 [==============================] - 1s 129ms/step - loss: 1.3456 - categorical_accuracy: 0.3592
# Epoch 72/1500
# 5/5 [==============================] - 1s 128ms/step - loss: 1.2613 - categorical_accuracy: 0.3099
# Epoch 73/1500
# 5/5 [==============================] - 1s 125ms/step - loss: 1.2013 - categorical_accuracy: 0.4507
# Epoch 74/1500
# 5/5 [==============================] - 1s 126ms/step - loss: 1.1824 - categorical_accuracy: 0.3873
# Epoch 75/1500
# 5/5 [==============================] - 1s 133ms/step - loss: 1.0794 - categorical_accuracy: 0.4437
# Epoch 76/1500
# 5/5 [==============================] - 1s 129ms/step - loss: 1.1340 - categorical_accuracy: 0.4859
# Epoch 77/1500
# 5/5 [==============================] - 1s 129ms/step - loss: 1.2290 - categorical_accuracy: 0.3803
# Epoch 78/1500
# 5/5 [==============================] - 1s 132ms/step - loss: 1.0931 - categorical_accuracy: 0.5070
# Epoch 79/1500
# 5/5 [==============================] - 1s 150ms/step - loss: 1.0290 - categorical_accuracy: 0.5211
# Epoch 80/1500
# 5/5 [==============================] - 1s 128ms/step - loss: 1.1005 - categorical_accuracy: 0.4296
# Epoch 81/1500
# 5/5 [==============================] - 1s 132ms/step - loss: 1.0174 - categorical_accuracy: 0.5000
# Epoch 82/1500
# 5/5 [==============================] - 1s 132ms/step - loss: 1.2961 - categorical_accuracy: 0.3944
# Epoch 83/1500
# 5/5 [==============================] - 1s 148ms/step - loss: 1.0067 - categorical_accuracy: 0.5352
# Epoch 84/1500
# 5/5 [==============================] - 1s 133ms/step - loss: 1.0496 - categorical_accuracy: 0.4577
# Epoch 85/1500
# 5/5 [==============================] - 1s 150ms/step - loss: 0.9682 - categorical_accuracy: 0.5775
# Epoch 86/1500
# 5/5 [==============================] - 1s 145ms/step - loss: 0.8946 - categorical_accuracy: 0.5845
# Epoch 87/1500
# 5/5 [==============================] - 1s 138ms/step - loss: 0.8865 - categorical_accuracy: 0.6056
# Epoch 88/1500
# 5/5 [==============================] - 1s 140ms/step - loss: 0.9897 - categorical_accuracy: 0.5211
# Epoch 89/1500
# 5/5 [==============================] - 1s 142ms/step - loss: 0.9831 - categorical_accuracy: 0.5493
# Epoch 90/1500
# 5/5 [==============================] - 1s 138ms/step - loss: 0.8766 - categorical_accuracy: 0.5634
# Epoch 91/1500
# 5/5 [==============================] - 1s 138ms/step - loss: 0.9395 - categorical_accuracy: 0.5704
# Epoch 92/1500
# 5/5 [==============================] - 1s 142ms/step - loss: 0.9428 - categorical_accuracy: 0.5563
# Epoch 93/1500
# 5/5 [==============================] - 1s 140ms/step - loss: 0.8808 - categorical_accuracy: 0.5775
# Epoch 94/1500
# 5/5 [==============================] - 1s 138ms/step - loss: 0.8049 - categorical_accuracy: 0.6338
# Epoch 95/1500
# 5/5 [==============================] - 1s 142ms/step - loss: 0.9283 - categorical_accuracy: 0.5634
# Epoch 96/1500
# 5/5 [==============================] - 1s 142ms/step - loss: 0.9729 - categorical_accuracy: 0.5493
# Epoch 97/1500
# 5/5 [==============================] - 1s 144ms/step - loss: 0.9039 - categorical_accuracy: 0.6197
# Epoch 98/1500
# 5/5 [==============================] - 1s 145ms/step - loss: 0.8849 - categorical_accuracy: 0.5634
# Epoch 99/1500
# 5/5 [==============================] - 1s 141ms/step - loss: 1.0128 - categorical_accuracy: 0.5634
# Epoch 100/1500
# 5/5 [==============================] - 1s 140ms/step - loss: 1.0382 - categorical_accuracy: 0.5352
# Epoch 101/1500
# 5/5 [==============================] - 1s 141ms/step - loss: 0.9097 - categorical_accuracy: 0.6268
# Epoch 102/1500
# 5/5 [==============================] - 1s 136ms/step - loss: 0.9178 - categorical_accuracy: 0.5986
# Epoch 103/1500
# 5/5 [==============================] - 1s 139ms/step - loss: 3.4312 - categorical_accuracy: 0.4718
# Epoch 104/1500
# 5/5 [==============================] - 1s 142ms/step - loss: 2.5970 - categorical_accuracy: 0.1761
# Epoch 105/1500
# 5/5 [==============================] - 1s 141ms/step - loss: 1.8993 - categorical_accuracy: 0.2113
# Epoch 106/1500
# 5/5 [==============================] - 1s 145ms/step - loss: 2.6390 - categorical_accuracy: 0.2958
# Epoch 107/1500
# 5/5 [==============================] - 1s 143ms/step - loss: 1.5659 - categorical_accuracy: 0.2746
# Epoch 108/1500
# 5/5 [==============================] - 1s 143ms/step - loss: 1.5160 - categorical_accuracy: 0.2887
# Epoch 109/1500
# 5/5 [==============================] - 1s 140ms/step - loss: 1.4648 - categorical_accuracy: 0.3099
# Epoch 110/1500
# 5/5 [==============================] - 1s 146ms/step - loss: 1.4250 - categorical_accuracy: 0.3380
# Epoch 111/1500
# 5/5 [==============================] - 1s 146ms/step - loss: 1.3613 - categorical_accuracy: 0.3380
# Epoch 112/1500
# 5/5 [==============================] - 1s 147ms/step - loss: 1.3230 - categorical_accuracy: 0.3873
# Epoch 113/1500
# 5/5 [==============================] - 1s 150ms/step - loss: 1.6578 - categorical_accuracy: 0.1972
# Epoch 114/1500
# 5/5 [==============================] - 1s 150ms/step - loss: 2.1578 - categorical_accuracy: 0.2746
# Epoch 115/1500
# 5/5 [==============================] - 1s 142ms/step - loss: 1.6749 - categorical_accuracy: 0.2254
# Epoch 116/1500
# 5/5 [==============================] - 1s 142ms/step - loss: 4.5994 - categorical_accuracy: 0.2324
# Epoch 117/1500
# 5/5 [==============================] - 1s 140ms/step - loss: 124.6951 - categorical_accuracy: 0.3028
# Epoch 118/1500
# 5/5 [==============================] - 1s 145ms/step - loss: 7299.9106 - categorical_accuracy: 0.2324
# Epoch 119/1500
# 5/5 [==============================] - 1s 149ms/step - loss: 2884.1797 - categorical_accuracy: 0.1901
# Epoch 120/1500
# 5/5 [==============================] - 1s 147ms/step - loss: 10666.4219 - categorical_accuracy: 0.1549
# Epoch 121/1500
# 5/5 [==============================] - 1s 142ms/step - loss: 6994.4028 - categorical_accuracy: 0.1972
# Epoch 122/1500
# 5/5 [==============================] - 1s 140ms/step - loss: 11378.1191 - categorical_accuracy: 0.2183
# Epoch 123/1500
# 5/5 [==============================] - 1s 142ms/step - loss: 1877.1318 - categorical_accuracy: 0.2394
# Epoch 124/1500
# 5/5 [==============================] - 1s 167ms/step - loss: 1584.0442 - categorical_accuracy: 0.2535
# Epoch 125/1500
# 5/5 [==============================] - 1s 155ms/step - loss: 724.6354 - categorical_accuracy: 0.1972
# Epoch 126/1500
# 5/5 [==============================] - 1s 141ms/step - loss: 32.0427 - categorical_accuracy: 0.2113
# Epoch 127/1500
# 5/5 [==============================] - 1s 155ms/step - loss: 33.2512 - categorical_accuracy: 0.1549
# Epoch 128/1500
# 5/5 [==============================] - 1s 140ms/step - loss: 116.9635 - categorical_accuracy: 0.1761
# Epoch 129/1500
# 5/5 [==============================] - 1s 136ms/step - loss: 129.3512 - categorical_accuracy: 0.2465
# Epoch 130/1500
# 5/5 [==============================] - 1s 134ms/step - loss: 52.3937 - categorical_accuracy: 0.1549
# Epoch 131/1500
# 5/5 [==============================] - 1s 135ms/step - loss: 62.8780 - categorical_accuracy: 0.2324
# Epoch 132/1500
# 5/5 [==============================] - 1s 136ms/step - loss: 746.7322 - categorical_accuracy: 0.1901
# Epoch 133/1500
# 5/5 [==============================] - 1s 135ms/step - loss: 940.2036 - categorical_accuracy: 0.2042
# Epoch 134/1500
# 5/5 [==============================] - 1s 135ms/step - loss: 1015.5250 - categorical_accuracy: 0.1972
# Epoch 135/1500
# 5/5 [==============================] - 1s 134ms/step - loss: 859.4838 - categorical_accuracy: 0.2042
# Epoch 136/1500
# 5/5 [==============================] - 1s 136ms/step - loss: 571.4720 - categorical_accuracy: 0.1972
# Epoch 137/1500
# 5/5 [==============================] - 1s 136ms/step - loss: 697.1512 - categorical_accuracy: 0.1972
# Epoch 138/1500
# 5/5 [==============================] - 1s 134ms/step - loss: 473.8393 - categorical_accuracy: 0.1972
# Epoch 139/1500
# 5/5 [==============================] - 1s 134ms/step - loss: 222.2573 - categorical_accuracy: 0.1972
# Epoch 140/1500
# 5/5 [==============================] - 1s 135ms/step - loss: 212.5644 - categorical_accuracy: 0.2113
# Epoch 141/1500
# 5/5 [==============================] - 1s 129ms/step - loss: 185.5025 - categorical_accuracy: 0.2113
# Epoch 142/1500
# 5/5 [==============================] - 1s 134ms/step - loss: 104.5072 - categorical_accuracy: 0.2113
# Epoch 143/1500
# 5/5 [==============================] - 1s 134ms/step - loss: 32.6553 - categorical_accuracy: 0.1972
# Epoch 144/1500
# 5/5 [==============================] - 1s 132ms/step - loss: 61.9045 - categorical_accuracy: 0.2042
# Epoch 145/1500
# 5/5 [==============================] - 1s 134ms/step - loss: 18.1369 - categorical_accuracy: 0.2042
# Epoch 146/1500
# 5/5 [==============================] - 1s 133ms/step - loss: 26.4480 - categorical_accuracy: 0.2113
# Epoch 147/1500
# 5/5 [==============================] - 1s 137ms/step - loss: 23.7214 - categorical_accuracy: 0.2113
# Epoch 148/1500
# 5/5 [==============================] - 1s 138ms/step - loss: 9.0794 - categorical_accuracy: 0.2183
# Epoch 149/1500
# 5/5 [==============================] - 1s 139ms/step - loss: 19.3725 - categorical_accuracy: 0.2113
# Epoch 150/1500
# 5/5 [==============================] - 1s 134ms/step - loss: 25.2702 - categorical_accuracy: 0.2042
# Epoch 151/1500
# 5/5 [==============================] - 1s 132ms/step - loss: 69.3504 - categorical_accuracy: 0.2113
# Epoch 152/1500
# 5/5 [==============================] - 1s 143ms/step - loss: 28.8428 - categorical_accuracy: 0.2183
# Epoch 153/1500
# 5/5 [==============================] - 1s 134ms/step - loss: 68.4904 - categorical_accuracy: 0.2113
# Epoch 154/1500
# 5/5 [==============================] - 1s 137ms/step - loss: 71.9129 - categorical_accuracy: 0.2113
# Epoch 155/1500
# 5/5 [==============================] - 1s 138ms/step - loss: 40.5735 - categorical_accuracy: 0.2113
# Epoch 156/1500
# 5/5 [==============================] - 1s 138ms/step - loss: 57.3202 - categorical_accuracy: 0.2183
# Epoch 157/1500
# 5/5 [==============================] - 1s 142ms/step - loss: 53.8183 - categorical_accuracy: 0.2183
# Epoch 158/1500
# 5/5 [==============================] - 1s 135ms/step - loss: 48.5061 - categorical_accuracy: 0.2113
# Epoch 159/1500
# 5/5 [==============================] - 1s 137ms/step - loss: 51.5176 - categorical_accuracy: 0.2113
# Epoch 160/1500
# 5/5 [==============================] - 1s 136ms/step - loss: 40.2381 - categorical_accuracy: 0.2113
# Epoch 161/1500
# 5/5 [==============================] - 1s 138ms/step - loss: 22.1725 - categorical_accuracy: 0.2183
# Epoch 162/1500
# 5/5 [==============================] - 1s 142ms/step - loss: 25.4146 - categorical_accuracy: 0.2113
# Epoch 163/1500
# 5/5 [==============================] - 1s 139ms/step - loss: 18.9417 - categorical_accuracy: 0.2042
# Epoch 164/1500
# 5/5 [==============================] - 1s 138ms/step - loss: 22.8103 - categorical_accuracy: 0.2183
# Epoch 165/1500
# 5/5 [==============================] - 1s 141ms/step - loss: 25.9753 - categorical_accuracy: 0.2113
# Epoch 166/1500
# 5/5 [==============================] - 1s 139ms/step - loss: 40.0780 - categorical_accuracy: 0.2113
# Epoch 167/1500
# 5/5 [==============================] - 1s 143ms/step - loss: 30.5288 - categorical_accuracy: 0.2183
# Epoch 168/1500
# 5/5 [==============================] - 1s 141ms/step - loss: 14.2937 - categorical_accuracy: 0.2113
# Epoch 169/1500
# 5/5 [==============================] - 1s 140ms/step - loss: 13.7567 - categorical_accuracy: 0.2042
# Epoch 170/1500
# 5/5 [==============================] - 1s 134ms/step - loss: 11.4821 - categorical_accuracy: 0.2042
# Epoch 171/1500
# 5/5 [==============================] - 1s 137ms/step - loss: 19.2734 - categorical_accuracy: 0.2254
# Epoch 172/1500
# 5/5 [==============================] - 1s 136ms/step - loss: 11.5275 - categorical_accuracy: 0.2113
# Epoch 173/1500
# 5/5 [==============================] - 1s 138ms/step - loss: 20.9141 - categorical_accuracy: 0.2183
# Epoch 174/1500
# 5/5 [==============================] - 1s 139ms/step - loss: 6.2965 - categorical_accuracy: 0.2254
# Epoch 175/1500
# 5/5 [==============================] - 1s 147ms/step - loss: 56.3501 - categorical_accuracy: 0.2254
# Epoch 176/1500
# 5/5 [==============================] - 1s 147ms/step - loss: 50.5907 - categorical_accuracy: 0.2254
# Epoch 177/1500
# 5/5 [==============================] - 1s 150ms/step - loss: 10.5539 - categorical_accuracy: 0.2113
# Epoch 178/1500
# 5/5 [==============================] - 1s 141ms/step - loss: 12.7585 - categorical_accuracy: 0.2183
# Epoch 179/1500
# 5/5 [==============================] - 1s 144ms/step - loss: 16.2132 - categorical_accuracy: 0.2254
# Epoch 180/1500
# 5/5 [==============================] - 1s 141ms/step - loss: 17.2811 - categorical_accuracy: 0.2183
# Epoch 181/1500
# 5/5 [==============================] - 1s 142ms/step - loss: 47.6202 - categorical_accuracy: 0.2183
# Epoch 182/1500
# 5/5 [==============================] - 1s 144ms/step - loss: 12.6550 - categorical_accuracy: 0.2254
# Epoch 183/1500
# 5/5 [==============================] - 1s 145ms/step - loss: 11.1469 - categorical_accuracy: 0.2254
# Epoch 184/1500
# 5/5 [==============================] - 1s 152ms/step - loss: 10.1122 - categorical_accuracy: 0.2254
# Epoch 185/1500
# 5/5 [==============================] - 1s 146ms/step - loss: 19.2789 - categorical_accuracy: 0.2183
# Epoch 186/1500
# 5/5 [==============================] - 1s 136ms/step - loss: 7.7254 - categorical_accuracy: 0.2254
# Epoch 187/1500
# 5/5 [==============================] - 1s 141ms/step - loss: 40.4043 - categorical_accuracy: 0.2254
# Epoch 188/1500
# 5/5 [==============================] - 1s 145ms/step - loss: 30.3767 - categorical_accuracy: 0.2183
# Epoch 189/1500
# 5/5 [==============================] - 1s 152ms/step - loss: 27.7153 - categorical_accuracy: 0.2183
# Epoch 190/1500
# 5/5 [==============================] - 1s 150ms/step - loss: 10.3424 - categorical_accuracy: 0.2254
# Epoch 191/1500
# 5/5 [==============================] - 1s 144ms/step - loss: 19.6504 - categorical_accuracy: 0.2254
# Epoch 192/1500
# 5/5 [==============================] - 1s 144ms/step - loss: 10.9837 - categorical_accuracy: 0.2254
# Epoch 193/1500
# 5/5 [==============================] - 1s 142ms/step - loss: 25.0342 - categorical_accuracy: 0.2183
# Epoch 194/1500
# 5/5 [==============================] - 1s 141ms/step - loss: 8.3457 - categorical_accuracy: 0.2183
# Epoch 195/1500
# 5/5 [==============================] - 1s 149ms/step - loss: 34.4799 - categorical_accuracy: 0.2254
# Epoch 196/1500
# 5/5 [==============================] - 1s 149ms/step - loss: 63.9887 - categorical_accuracy: 0.2254
# Epoch 197/1500
# 5/5 [==============================] - 1s 165ms/step - loss: 40.5084 - categorical_accuracy: 0.2254
# Epoch 198/1500
# 5/5 [==============================] - 1s 161ms/step - loss: 3.3159 - categorical_accuracy: 0.2183
# Epoch 199/1500
# 5/5 [==============================] - 1s 150ms/step - loss: 61.6413 - categorical_accuracy: 0.2183
# Epoch 200/1500
# 5/5 [==============================] - 1s 171ms/step - loss: 59.6863 - categorical_accuracy: 0.2183
# Epoch 201/1500
# 5/5 [==============================] - 1s 149ms/step - loss: 26.8727 - categorical_accuracy: 0.2113
# Epoch 202/1500
# 5/5 [==============================] - 1s 174ms/step - loss: 3.1565 - categorical_accuracy: 0.2254
# Epoch 203/1500
# 5/5 [==============================] - 1s 174ms/step - loss: 25.8132 - categorical_accuracy: 0.2183
# Epoch 204/1500
# 5/5 [==============================] - 1s 149ms/step - loss: 2.3483 - categorical_accuracy: 0.2254
# Epoch 205/1500
# 5/5 [==============================] - 1s 139ms/step - loss: 12.6526 - categorical_accuracy: 0.2254
# Epoch 206/1500
# 5/5 [==============================] - 1s 141ms/step - loss: 10.7761 - categorical_accuracy: 0.2183
# Epoch 207/1500
# 5/5 [==============================] - 1s 138ms/step - loss: 12.3655 - categorical_accuracy: 0.2183
# Epoch 208/1500
# 5/5 [==============================] - 1s 141ms/step - loss: 8.4637 - categorical_accuracy: 0.2254
# Epoch 209/1500
# 5/5 [==============================] - 1s 147ms/step - loss: 17.1646 - categorical_accuracy: 0.2183
# Epoch 210/1500
# 5/5 [==============================] - 1s 147ms/step - loss: 1.5633 - categorical_accuracy: 0.2324
# Epoch 211/1500
# 5/5 [==============================] - 1s 148ms/step - loss: 13.8415 - categorical_accuracy: 0.2254
# Epoch 212/1500
# 5/5 [==============================] - 1s 163ms/step - loss: 17.9835 - categorical_accuracy: 0.2183
# Epoch 213/1500
# 5/5 [==============================] - 1s 186ms/step - loss: 7.5694 - categorical_accuracy: 0.2183
# Epoch 214/1500
# 5/5 [==============================] - 1s 160ms/step - loss: 20.8167 - categorical_accuracy: 0.2254
# Epoch 215/1500
# 5/5 [==============================] - 1s 143ms/step - loss: 24.8493 - categorical_accuracy: 0.2254
# Epoch 216/1500
# 5/5 [==============================] - 1s 153ms/step - loss: 8.4822 - categorical_accuracy: 0.2254
# Epoch 217/1500
# 5/5 [==============================] - 1s 181ms/step - loss: 10.7772 - categorical_accuracy: 0.2183
# Epoch 218/1500
# 5/5 [==============================] - 1s 152ms/step - loss: 10.4976 - categorical_accuracy: 0.2254
# Epoch 219/1500
# 5/5 [==============================] - 1s 142ms/step - loss: 14.7892 - categorical_accuracy: 0.2183
# Epoch 220/1500
# 5/5 [==============================] - 1s 146ms/step - loss: 9.8422 - categorical_accuracy: 0.2183
# Epoch 221/1500
# 5/5 [==============================] - 1s 145ms/step - loss: 5.3393 - categorical_accuracy: 0.2183
# Epoch 222/1500
# 5/5 [==============================] - 1s 161ms/step - loss: 29.1303 - categorical_accuracy: 0.2183
# Epoch 223/1500
# 5/5 [==============================] - 1s 171ms/step - loss: 18.5047 - categorical_accuracy: 0.2183
# Epoch 224/1500
# 5/5 [==============================] - 1s 149ms/step - loss: 6.9648 - categorical_accuracy: 0.2183
# Epoch 225/1500
# 5/5 [==============================] - 1s 157ms/step - loss: 21.9928 - categorical_accuracy: 0.2183
# Epoch 226/1500
# 5/5 [==============================] - 1s 173ms/step - loss: 25.8128 - categorical_accuracy: 0.2183
# Epoch 227/1500
# 5/5 [==============================] - 1s 163ms/step - loss: 18.3959 - categorical_accuracy: 0.2113
# Epoch 228/1500
# 5/5 [==============================] - 1s 145ms/step - loss: 7.3601 - categorical_accuracy: 0.2113
# Epoch 229/1500
# 5/5 [==============================] - 1s 145ms/step - loss: 1.6244 - categorical_accuracy: 0.2254
# Epoch 230/1500
# 5/5 [==============================] - 1s 145ms/step - loss: 14.3150 - categorical_accuracy: 0.2113
# Epoch 231/1500
# 5/5 [==============================] - 1s 148ms/step - loss: 1.8938 - categorical_accuracy: 0.2183
# Epoch 232/1500
# 5/5 [==============================] - 1s 149ms/step - loss: 14.0235 - categorical_accuracy: 0.2254
# Epoch 233/1500
# 5/5 [==============================] - 1s 146ms/step - loss: 18.6613 - categorical_accuracy: 0.2183
# Epoch 234/1500
# 5/5 [==============================] - 1s 150ms/step - loss: 40.6887 - categorical_accuracy: 0.2183
# Epoch 235/1500
# 5/5 [==============================] - 1s 153ms/step - loss: 31.0301 - categorical_accuracy: 0.2254
# Epoch 236/1500
# 5/5 [==============================] - 1s 151ms/step - loss: 60.1363 - categorical_accuracy: 0.2183
# Epoch 237/1500
# 5/5 [==============================] - 1s 148ms/step - loss: 57.9644 - categorical_accuracy: 0.2183
# Epoch 238/1500
# 5/5 [==============================] - 1s 149ms/step - loss: 12.1303 - categorical_accuracy: 0.2254
# Epoch 239/1500
# 5/5 [==============================] - 1s 149ms/step - loss: 30.9660 - categorical_accuracy: 0.2254
# Epoch 240/1500
# 5/5 [==============================] - 1s 150ms/step - loss: 26.9278 - categorical_accuracy: 0.2254
# Epoch 241/1500
# 5/5 [==============================] - 1s 149ms/step - loss: 24.4230 - categorical_accuracy: 0.2113
# Epoch 242/1500
# 5/5 [==============================] - 1s 150ms/step - loss: 30.0491 - categorical_accuracy: 0.2183
# Epoch 243/1500
# 5/5 [==============================] - 1s 143ms/step - loss: 2.7066 - categorical_accuracy: 0.2254
# Epoch 244/1500
# 5/5 [==============================] - 1s 148ms/step - loss: 10.1395 - categorical_accuracy: 0.2183
# Epoch 245/1500
# 5/5 [==============================] - 1s 148ms/step - loss: 10.9173 - categorical_accuracy: 0.2254
# Epoch 246/1500
# 5/5 [==============================] - 1s 143ms/step - loss: 8.2354 - categorical_accuracy: 0.2183
# Epoch 247/1500
# 5/5 [==============================] - 1s 146ms/step - loss: 9.8165 - categorical_accuracy: 0.2254
# Epoch 248/1500
# 5/5 [==============================] - 1s 146ms/step - loss: 12.7684 - categorical_accuracy: 0.2183
# Epoch 249/1500
# 5/5 [==============================] - 1s 146ms/step - loss: 5.1822 - categorical_accuracy: 0.2113
# Epoch 250/1500
# 5/5 [==============================] - 1s 145ms/step - loss: 6.8842 - categorical_accuracy: 0.2254
# Epoch 251/1500
# 5/5 [==============================] - 1s 160ms/step - loss: 13.5174 - categorical_accuracy: 0.2183
# Epoch 252/1500
# 5/5 [==============================] - 1s 170ms/step - loss: 1.5629 - categorical_accuracy: 0.2324
# Epoch 253/1500
# 5/5 [==============================] - 1s 163ms/step - loss: 21.9197 - categorical_accuracy: 0.2254
# Epoch 254/1500
# 5/5 [==============================] - 1s 147ms/step - loss: 4.7668 - categorical_accuracy: 0.2183
# Epoch 255/1500
# 5/5 [==============================] - 1s 152ms/step - loss: 27.7666 - categorical_accuracy: 0.2183
# Epoch 256/1500
# 5/5 [==============================] - 1s 149ms/step - loss: 21.4754 - categorical_accuracy: 0.2183
# Epoch 257/1500
# 5/5 [==============================] - 1s 145ms/step - loss: 28.7889 - categorical_accuracy: 0.2183
# Epoch 258/1500
# 5/5 [==============================] - 1s 140ms/step - loss: 31.7914 - categorical_accuracy: 0.2254
# Epoch 259/1500
# 5/5 [==============================] - 1s 145ms/step - loss: 20.1255 - categorical_accuracy: 0.2183
# Epoch 260/1500
# 5/5 [==============================] - 1s 149ms/step - loss: 1.5629 - categorical_accuracy: 0.2324
# Epoch 261/1500
# 5/5 [==============================] - 1s 147ms/step - loss: 7.2372 - categorical_accuracy: 0.2183
# Epoch 262/1500
# 5/5 [==============================] - 1s 144ms/step - loss: 17.6260 - categorical_accuracy: 0.2183
# Epoch 263/1500
# 5/5 [==============================] - 1s 145ms/step - loss: 4.4193 - categorical_accuracy: 0.2183
# Epoch 264/1500
# 5/5 [==============================] - 1s 140ms/step - loss: 9.5587 - categorical_accuracy: 0.2183
# Epoch 265/1500
# 5/5 [==============================] - 1s 149ms/step - loss: 9.8096 - categorical_accuracy: 0.2254
# Epoch 266/1500
# 5/5 [==============================] - 1s 152ms/step - loss: 6.9681 - categorical_accuracy: 0.2113
# Epoch 267/1500
# 5/5 [==============================] - 1s 156ms/step - loss: 4.9767 - categorical_accuracy: 0.2183
# Epoch 268/1500
# 5/5 [==============================] - 1s 148ms/step - loss: 32.0202 - categorical_accuracy: 0.2254
# Epoch 269/1500
# 5/5 [==============================] - 1s 152ms/step - loss: 43.9097 - categorical_accuracy: 0.2254
# Epoch 270/1500
# 5/5 [==============================] - 1s 146ms/step - loss: 32.4009 - categorical_accuracy: 0.2254
# Epoch 271/1500
# 5/5 [==============================] - 1s 146ms/step - loss: 17.9667 - categorical_accuracy: 0.2183
# Epoch 272/1500
# 5/5 [==============================] - 1s 145ms/step - loss: 6.6560 - categorical_accuracy: 0.2183
# Epoch 273/1500
# 5/5 [==============================] - 1s 153ms/step - loss: 22.9402 - categorical_accuracy: 0.2254
# Epoch 274/1500
# 5/5 [==============================] - 1s 148ms/step - loss: 19.7574 - categorical_accuracy: 0.2254
# Epoch 275/1500
# 5/5 [==============================] - 1s 148ms/step - loss: 13.2715 - categorical_accuracy: 0.2183
# Epoch 276/1500
# 5/5 [==============================] - 1s 151ms/step - loss: 4.4621 - categorical_accuracy: 0.2254
# Epoch 277/1500
# 5/5 [==============================] - 1s 150ms/step - loss: 21.3443 - categorical_accuracy: 0.2254
# Epoch 278/1500
# 5/5 [==============================] - 1s 152ms/step - loss: 18.7232 - categorical_accuracy: 0.2183
# Epoch 279/1500
# 5/5 [==============================] - 1s 151ms/step - loss: 3.0309 - categorical_accuracy: 0.2254
# Epoch 280/1500
# 5/5 [==============================] - 1s 152ms/step - loss: 17.7759 - categorical_accuracy: 0.2254
# Epoch 281/1500
# 5/5 [==============================] - 1s 163ms/step - loss: 7.5662 - categorical_accuracy: 0.2254
# Epoch 282/1500
# 5/5 [==============================] - 1s 155ms/step - loss: 17.1949 - categorical_accuracy: 0.2183
# Epoch 283/1500
# 5/5 [==============================] - 1s 146ms/step - loss: 52.5434 - categorical_accuracy: 0.2183
# Epoch 284/1500
# 5/5 [==============================] - 1s 149ms/step - loss: 324.9988 - categorical_accuracy: 0.1690
# Epoch 285/1500
# 5/5 [==============================] - 1s 157ms/step - loss: 118.1363 - categorical_accuracy: 0.2958
# Epoch 286/1500
# 5/5 [==============================] - 1s 154ms/step - loss: 114.1862 - categorical_accuracy: 0.2183
# Epoch 287/1500
# 5/5 [==============================] - 1s 152ms/step - loss: 77.7116 - categorical_accuracy: 0.1972
# Epoch 288/1500
# 5/5 [==============================] - 1s 151ms/step - loss: 33.3416 - categorical_accuracy: 0.2042
# Epoch 289/1500
# 5/5 [==============================] - 1s 155ms/step - loss: 50.1450 - categorical_accuracy: 0.2042
# Epoch 290/1500
# 5/5 [==============================] - 1s 147ms/step - loss: 35.0989 - categorical_accuracy: 0.2676
# Epoch 291/1500
# 5/5 [==============================] - 1s 149ms/step - loss: 33.6613 - categorical_accuracy: 0.2113
# Epoch 292/1500
# 5/5 [==============================] - 1s 152ms/step - loss: 16.6858 - categorical_accuracy: 0.2042
# Epoch 293/1500
# 5/5 [==============================] - 1s 159ms/step - loss: 16.1682 - categorical_accuracy: 0.1901
# Epoch 294/1500
# 5/5 [==============================] - 1s 160ms/step - loss: 303.4230 - categorical_accuracy: 0.2394
# Epoch 295/1500
# 5/5 [==============================] - 1s 155ms/step - loss: 467.7347 - categorical_accuracy: 0.1901
# Epoch 296/1500
# 5/5 [==============================] - 1s 154ms/step - loss: 143.3777 - categorical_accuracy: 0.2113
# Epoch 297/1500
# 5/5 [==============================] - 1s 166ms/step - loss: 65.6208 - categorical_accuracy: 0.2113
# Epoch 298/1500
# 5/5 [==============================] - 1s 190ms/step - loss: 98.3572 - categorical_accuracy: 0.2465
# Epoch 299/1500
# 5/5 [==============================] - 1s 180ms/step - loss: 55.6271 - categorical_accuracy: 0.2817
# Epoch 300/1500
# 5/5 [==============================] - 1s 156ms/step - loss: 21.5832 - categorical_accuracy: 0.2113
# Epoch 301/1500
# 5/5 [==============================] - 1s 154ms/step - loss: 25.2497 - categorical_accuracy: 0.2254
# Epoch 302/1500
# 5/5 [==============================] - 1s 156ms/step - loss: 1.4879 - categorical_accuracy: 0.2324
# Epoch 303/1500
# 5/5 [==============================] - 1s 157ms/step - loss: 21.5127 - categorical_accuracy: 0.2113
# Epoch 304/1500
# 5/5 [==============================] - 1s 153ms/step - loss: 8.3115 - categorical_accuracy: 0.1901
# Epoch 305/1500
# 5/5 [==============================] - 1s 159ms/step - loss: 21.4033 - categorical_accuracy: 0.2042
# Epoch 306/1500
# 5/5 [==============================] - 1s 191ms/step - loss: 20.4710 - categorical_accuracy: 0.2042
# Epoch 307/1500
# 5/5 [==============================] - 1s 180ms/step - loss: 1.4802 - categorical_accuracy: 0.2183
# Epoch 308/1500
# 5/5 [==============================] - 1s 166ms/step - loss: 12.5249 - categorical_accuracy: 0.3099
# Epoch 309/1500
# 5/5 [==============================] - 1s 154ms/step - loss: 8.0469 - categorical_accuracy: 0.2183
# Epoch 310/1500
# 5/5 [==============================] - 1s 157ms/step - loss: 7.2863 - categorical_accuracy: 0.2958
# Epoch 311/1500
# 5/5 [==============================] - 1s 158ms/step - loss: 24.7854 - categorical_accuracy: 0.2746
# Epoch 312/1500
# 5/5 [==============================] - 1s 160ms/step - loss: 19.0386 - categorical_accuracy: 0.2887
# Epoch 313/1500
# 5/5 [==============================] - 1s 175ms/step - loss: 2.6670 - categorical_accuracy: 0.2958
# Epoch 314/1500
# 5/5 [==============================] - 1s 165ms/step - loss: 8.9817 - categorical_accuracy: 0.3239
# Epoch 315/1500
# 5/5 [==============================] - 1s 160ms/step - loss: 5.4153 - categorical_accuracy: 0.4155
# Epoch 316/1500
# 5/5 [==============================] - 1s 158ms/step - loss: 11.5731 - categorical_accuracy: 0.4437
# Epoch 317/1500
# 5/5 [==============================] - 1s 165ms/step - loss: 3.3855 - categorical_accuracy: 0.4014
# Epoch 318/1500
# 5/5 [==============================] - 1s 158ms/step - loss: 8.2156 - categorical_accuracy: 0.4014
# Epoch 319/1500
# 5/5 [==============================] - 1s 159ms/step - loss: 2.8612 - categorical_accuracy: 0.3873
# Epoch 320/1500
# 5/5 [==============================] - 1s 175ms/step - loss: 9.5484 - categorical_accuracy: 0.3380
# Epoch 321/1500
# 5/5 [==============================] - 1s 156ms/step - loss: 45.3618 - categorical_accuracy: 0.3310
# Epoch 322/1500
# 5/5 [==============================] - 1s 155ms/step - loss: 1.4166 - categorical_accuracy: 0.4507
# Epoch 323/1500
# 5/5 [==============================] - 1s 157ms/step - loss: 9.8467 - categorical_accuracy: 0.3803
# Epoch 324/1500
# 5/5 [==============================] - 1s 154ms/step - loss: 3.0457 - categorical_accuracy: 0.4507
# Epoch 325/1500
# 5/5 [==============================] - 1s 159ms/step - loss: 35.8295 - categorical_accuracy: 0.4507
# Epoch 326/1500
# 5/5 [==============================] - 1s 154ms/step - loss: 12.6938 - categorical_accuracy: 0.2817
# Epoch 327/1500
# 5/5 [==============================] - 1s 154ms/step - loss: 6.8783 - categorical_accuracy: 0.4789
# Epoch 328/1500
# 5/5 [==============================] - 1s 150ms/step - loss: 18.2875 - categorical_accuracy: 0.3380
# Epoch 329/1500
# 5/5 [==============================] - 1s 153ms/step - loss: 5.3537 - categorical_accuracy: 0.2113
# Epoch 330/1500
# 5/5 [==============================] - 1s 177ms/step - loss: 5.8417 - categorical_accuracy: 0.2183
# Epoch 331/1500
# 5/5 [==============================] - 1s 159ms/step - loss: 8.2698 - categorical_accuracy: 0.2254
# Epoch 332/1500
# 5/5 [==============================] - 1s 154ms/step - loss: 8.5319 - categorical_accuracy: 0.2254
# Epoch 333/1500
# 5/5 [==============================] - 1s 164ms/step - loss: 4.9340 - categorical_accuracy: 0.2254
# Epoch 334/1500
# 5/5 [==============================] - 1s 154ms/step - loss: 3.3529 - categorical_accuracy: 0.2254
# Epoch 335/1500
# 5/5 [==============================] - 1s 150ms/step - loss: 3.8493 - categorical_accuracy: 0.2183
# Epoch 336/1500
# 5/5 [==============================] - 1s 157ms/step - loss: 4.2135 - categorical_accuracy: 0.2254
# Epoch 337/1500
# 5/5 [==============================] - 1s 164ms/step - loss: 8.1102 - categorical_accuracy: 0.2254
# Epoch 338/1500
# 5/5 [==============================] - 1s 171ms/step - loss: 5.3730 - categorical_accuracy: 0.2254
# Epoch 339/1500
# 5/5 [==============================] - 1s 147ms/step - loss: 9.2188 - categorical_accuracy: 0.2254
# Epoch 340/1500
# 5/5 [==============================] - 1s 163ms/step - loss: 5.7897 - categorical_accuracy: 0.2254
# Epoch 341/1500
# 5/5 [==============================] - 1s 159ms/step - loss: 5.2681 - categorical_accuracy: 0.2254
# Epoch 342/1500
# 5/5 [==============================] - 1s 158ms/step - loss: 3.2235 - categorical_accuracy: 0.2254
# Epoch 343/1500
# 5/5 [==============================] - 1s 180ms/step - loss: 6.6980 - categorical_accuracy: 0.2254
# Epoch 344/1500
# 5/5 [==============================] - 1s 160ms/step - loss: 6.0233 - categorical_accuracy: 0.2183
# Epoch 345/1500
# 5/5 [==============================] - 1s 159ms/step - loss: 3.5233 - categorical_accuracy: 0.2254
# Epoch 346/1500
# 5/5 [==============================] - 1s 153ms/step - loss: 3.1737 - categorical_accuracy: 0.2887
# Epoch 347/1500
# 5/5 [==============================] - 1s 154ms/step - loss: 5.4014 - categorical_accuracy: 0.2606
# Epoch 348/1500
# 5/5 [==============================] - 1s 158ms/step - loss: 3.6565 - categorical_accuracy: 0.2535
# Epoch 349/1500
# 5/5 [==============================] - 1s 163ms/step - loss: 5.5169 - categorical_accuracy: 0.3310
# Epoch 350/1500
# 5/5 [==============================] - 1s 153ms/step - loss: 3.8523 - categorical_accuracy: 0.3592
# Epoch 351/1500
# 5/5 [==============================] - 1s 158ms/step - loss: 2.1074 - categorical_accuracy: 0.2254
# Epoch 352/1500
# 5/5 [==============================] - 1s 163ms/step - loss: 10.9654 - categorical_accuracy: 0.2254
# Epoch 353/1500
# 5/5 [==============================] - 1s 163ms/step - loss: 8.3565 - categorical_accuracy: 0.2254
# Epoch 354/1500
# 5/5 [==============================] - 1s 162ms/step - loss: 11.3550 - categorical_accuracy: 0.2183
# Epoch 355/1500
# 5/5 [==============================] - 1s 187ms/step - loss: 12.4538 - categorical_accuracy: 0.2254
# Epoch 356/1500
# 5/5 [==============================] - 1s 171ms/step - loss: 8.5180 - categorical_accuracy: 0.2254
# Epoch 357/1500
# 5/5 [==============================] - 1s 162ms/step - loss: 2.3368 - categorical_accuracy: 0.2254
# Epoch 358/1500
# 5/5 [==============================] - 1s 159ms/step - loss: 4.3135 - categorical_accuracy: 0.2254
# Epoch 359/1500
# 5/5 [==============================] - 1s 155ms/step - loss: 5.6949 - categorical_accuracy: 0.2254
# Epoch 360/1500
# 5/5 [==============================] - 1s 155ms/step - loss: 4.6884 - categorical_accuracy: 0.2183
# Epoch 361/1500
# 5/5 [==============================] - 1s 153ms/step - loss: 3.0854 - categorical_accuracy: 0.2183
# Epoch 362/1500
# 5/5 [==============================] - 1s 162ms/step - loss: 2.7438 - categorical_accuracy: 0.2254
# Epoch 363/1500
# 5/5 [==============================] - 1s 159ms/step - loss: 4.7324 - categorical_accuracy: 0.2254
# Epoch 364/1500
# 5/5 [==============================] - 1s 149ms/step - loss: 3.2715 - categorical_accuracy: 0.2254
# Epoch 365/1500
# 5/5 [==============================] - 1s 153ms/step - loss: 6.3131 - categorical_accuracy: 0.2254
# Epoch 366/1500
# 5/5 [==============================] - 1s 153ms/step - loss: 4.6094 - categorical_accuracy: 0.2254
# Epoch 367/1500
# 5/5 [==============================] - 1s 161ms/step - loss: 4.7649 - categorical_accuracy: 0.2254
# Epoch 368/1500
# 5/5 [==============================] - 1s 157ms/step - loss: 4.0626 - categorical_accuracy: 0.2254
# Epoch 369/1500
# 5/5 [==============================] - 1s 151ms/step - loss: 4.7809 - categorical_accuracy: 0.2254
# Epoch 370/1500
# 5/5 [==============================] - 1s 149ms/step - loss: 6.9198 - categorical_accuracy: 0.2254
# Epoch 371/1500
# 5/5 [==============================] - 1s 156ms/step - loss: 4.2539 - categorical_accuracy: 0.2254
# Epoch 372/1500
# 5/5 [==============================] - 1s 151ms/step - loss: 4.9272 - categorical_accuracy: 0.2254
# Epoch 373/1500
# 5/5 [==============================] - 1s 156ms/step - loss: 4.9879 - categorical_accuracy: 0.2254
# Epoch 374/1500
# 5/5 [==============================] - 1s 152ms/step - loss: 1.8435 - categorical_accuracy: 0.2254
# Epoch 375/1500
# 5/5 [==============================] - 1s 154ms/step - loss: 8.9396 - categorical_accuracy: 0.2254
# Epoch 376/1500
# 5/5 [==============================] - 1s 157ms/step - loss: 8.2044 - categorical_accuracy: 0.2254
# Epoch 377/1500
# 5/5 [==============================] - 1s 154ms/step - loss: 1.5639 - categorical_accuracy: 0.2324
# Epoch 378/1500
# 5/5 [==============================] - 1s 156ms/step - loss: 4.8276 - categorical_accuracy: 0.2254
# Epoch 379/1500
# 5/5 [==============================] - 1s 155ms/step - loss: 1.9630 - categorical_accuracy: 0.2254
# Epoch 380/1500
# 5/5 [==============================] - 1s 155ms/step - loss: 6.9477 - categorical_accuracy: 0.2254
# Epoch 381/1500
# 5/5 [==============================] - 1s 158ms/step - loss: 6.7253 - categorical_accuracy: 0.2254
# Epoch 382/1500
# 5/5 [==============================] - 1s 156ms/step - loss: 1.5635 - categorical_accuracy: 0.2324
# Epoch 383/1500
# 5/5 [==============================] - 1s 161ms/step - loss: 4.9284 - categorical_accuracy: 0.2254
# Epoch 384/1500
# 5/5 [==============================] - 1s 155ms/step - loss: 2.9501 - categorical_accuracy: 0.2254
# Epoch 385/1500
# 5/5 [==============================] - 1s 158ms/step - loss: 5.9990 - categorical_accuracy: 0.2254
# Epoch 386/1500
# 5/5 [==============================] - 1s 158ms/step - loss: 5.4349 - categorical_accuracy: 0.2183
# Epoch 387/1500
# 5/5 [==============================] - 1s 156ms/step - loss: 1.8645 - categorical_accuracy: 0.2254
# Epoch 388/1500
# 5/5 [==============================] - 1s 157ms/step - loss: 3.2928 - categorical_accuracy: 0.2254
# Epoch 389/1500
# 5/5 [==============================] - 1s 153ms/step - loss: 1.7025 - categorical_accuracy: 0.2254
# Epoch 390/1500
# 5/5 [==============================] - 1s 158ms/step - loss: 7.4778 - categorical_accuracy: 0.2254
# Epoch 391/1500
# 5/5 [==============================] - 1s 154ms/step - loss: 6.6928 - categorical_accuracy: 0.2254
# Epoch 392/1500
# 3/5 [=================>............] - ETA: 0s - loss: 1.5894 - categorical_accuracy: 0.2500
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_6136/2303700141.py in <module>
# ----> 1 model.fit(X_train, y_train, epochs=1500, callbacks=[tb_callback])
#
# S:\Anaconda\lib\site-packages\keras\utils\traceback_utils.py in error_handler(*args, **kwargs)
#      62     filtered_tb = None
#      63     try:
# ---> 64       return fn(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# S:\Anaconda\lib\site-packages\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1407                 _r=1):
#    1408               callbacks.on_train_batch_begin(step)
# -> 1409               tmp_logs = self.train_function(iterator)
#    1410               if data_handler.should_sync:
#    1411                 context.async_wait()
#
# S:\Anaconda\lib\site-packages\tensorflow\python\util\traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# S:\Anaconda\lib\site-packages\tensorflow\python\eager\def_function.py in __call__(self, *args, **kwds)
#     913
#     914       with OptionalXlaContext(self._jit_compile):
# --> 915         result = self._call(*args, **kwds)
#     916
#     917       new_tracing_count = self.experimental_get_tracing_count()
#
# S:\Anaconda\lib\site-packages\tensorflow\python\eager\def_function.py in _call(self, *args, **kwds)
#     945       # In this case we have created variables on the first call, so we run the
#     946       # defunned version which is guaranteed to never create variables.
# --> 947       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     948     elif self._stateful_fn is not None:
#     949       # Release the lock early so that multiple threads can perform the call
#
# S:\Anaconda\lib\site-packages\tensorflow\python\eager\function.py in __call__(self, *args, **kwargs)
#    2451       (graph_function,
#    2452        filtered_flat_args) = self._maybe_define_function(args, kwargs)
# -> 2453     return graph_function._call_flat(
#    2454         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#    2455
#
# S:\Anaconda\lib\site-packages\tensorflow\python\eager\function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1858         and executing_eagerly):
#    1859       # No tape is watching; skip to running the function.
# -> 1860       return self._build_call_outputs(self._inference_function.call(
#    1861           ctx, args, cancellation_manager=cancellation_manager))
#    1862     forward_backward = self._select_forward_and_backward_functions(
#
# S:\Anaconda\lib\site-packages\tensorflow\python\eager\function.py in call(self, ctx, args, cancellation_manager)
#     495       with _InterpolateFunctionError(self):
#     496         if cancellation_manager is None:
# --> 497           outputs = execute.execute(
#     498               str(self.signature.name),
#     499               num_outputs=self._num_outputs,
#
# S:\Anaconda\lib\site-packages\tensorflow\python\eager\execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      52   try:
#      53     ctx.ensure_initialized()
# ---> 54     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      55                                         inputs, attrs, num_outputs)
#      56   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 30, 64)            442112
#
#  lstm_1 (LSTM)               (None, 30, 128)           98816
#
#  lstm_2 (LSTM)               (None, 64)                49408
#
#  dense (Dense)               (None, 64)                4160
#
#  dense_1 (Dense)             (None, 32)                2080
#
#  dense_2 (Dense)             (None, 5)                 165
#
# =================================================================
# Total params: 596,741
# Trainable params: 596,741
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # 8. Make Predictions

# %%
res = model.predict(X_test)
# Out:
# 1/1 [==============================] - 2s 2s/step

# %%
actions[np.argmax(res[4])]
# Out:
# 'thanks'

# %%
actions[np.argmax(y_test[4])]
# Out:
# 'No'

# %% [markdown]
# # 9. Save Weights

# %%
    model.save('action.h5')

# %%
del model

# %%
model.load_weights('action.h5')

# %% [markdown]
# # 10. Evaluation using Confusion Matrix and Accuracy

# %%
from sklearn.metrics import multilabel_confusion_matrix, accuracy_score

# %%
yhat = model.predict(X_test)
# Out:
# 1/1 [==============================] - 0s 58ms/step

# %%
ytrue = np.argmax(y_test, axis=1).tolist()
yhat = np.argmax(yhat, axis=1).tolist()

# %%
multilabel_confusion_matrix(ytrue, yhat)
# Out:
# array([[[7, 0],
#         [1, 0]],
#
#        [[5, 0],
#         [3, 0]],
#
#        [[7, 0],
#         [1, 0]],
#
#        [[7, 0],
#         [1, 0]],
#
#        [[0, 6],
#         [0, 2]]], dtype=int64)

# %%
accuracy_score(ytrue, yhat)
# Out:
# 0.25

# %% [markdown]
# # 11. Test in Real Time

# %%
from scipy import stats

# %%
colors = [(245,117,16), (117,245,16), (16,117,245), (128, 128, 0), (128, 0, 128)]
def prob_viz(res, actions, input_frame, colors):
    output_frame = input_frame.copy()
    for num, prob in enumerate(res):
        cv2.rectangle(output_frame, (0,60+num*40), (int(prob*100), 90+num*40), colors[num], -1)
        cv2.putText(output_frame, actions[num], (0, 85+num*40), cv2.FONT_HERSHEY_SIMPLEX, 1, (255,255,255), 2, cv2.LINE_AA)
        
    return output_frame

# %%
plt.figure(figsize=(18,18))
plt.imshow(prob_viz(res, actions, image, colors))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_23272/104962489.py in <module>
#       1 plt.figure(figsize=(18,18))
# ----> 2 plt.imshow(prob_viz(res, actions, image, colors))
#
# ~\AppData\Local\Temp/ipykernel_23272/4046413514.py in prob_viz(res, actions, input_frame, colors)
#       3     output_frame = input_frame.copy()
#       4     for num, prob in enumerate(res):
# ----> 5         cv2.rectangle(output_frame, (0,60+num*40), (int(prob*100), 90+num*40), colors[num], -1)
#       6         cv2.putText(output_frame, actions[num], (0, 85+num*40), cv2.FONT_HERSHEY_SIMPLEX, 1, (255,255,255), 2, cv2.LINE_AA)
#       7
#
# TypeError: only size-1 arrays can be converted to Python scalars

# %%
plt.figure(figsize=(18,18))
plt.imshow(prob_viz(res, actions, image, colors))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_21456/914121024.py in <module>
#       1 plt.figure(figsize=(18,18))
# ----> 2 plt.imshow(prob_viz(res, actions, image, colors))
#
# ~\AppData\Local\Temp/ipykernel_21456/2568779431.py in prob_viz(res, actions, input_frame, colors)
#       3     output_frame = input_frame.copy()
#       4     for num, prob in enumerate(res):
# ----> 5         cv2.rectangle(output_frame, (0,60+num*40), (int(prob*100), 90+num*40), colors[num], -1)
#       6         cv2.putText(output_frame, actions[num], (0, 85+num*40), cv2.FONT_HERSHEY_SIMPLEX, 1, (255,255,255), 2, cv2.LINE_AA)
#       7
#
# TypeError: only size-1 arrays can be converted to Python scalars

# %%
sequence = []
sentence = []
predictions = []
threshold = 0.5

cap = cv2.VideoCapture(0)

# Set mediapipe model
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    while cap.isOpened():

        # Read feed
        ret, frame = cap.read()

        # Make detections
        image, results = mediapipe_detection(frame, holistic)
        print(results)
        
        # Draw landmarks
        draw_styled_landmarks(image, results)
        
        # 2. Prediction logic
        keypoints = extract_keypoints(results)
        sequence.append(keypoints)
        sequence = sequence[-30:]
        
        if len(sequence) == 30:
            res = model.predict(np.expand_dims(sequence, axis=0))[0]
            print(actions[np.argmax(res)])
            predictions.append(np.argmax(res))
            
            #3. Viz logic
            if np.unique(predictions[-10:])[0]==np.argmax(res): 
                if res[np.argmax(res)] > threshold: 
                    
                    if len(sentence) > 0: 
                        if actions[np.argmax(res)] != sentence[-1]:
                            sentence.append(actions[np.argmax(res)])
                            with open("detected_actions.txt", "a") as f:
                                f.write(actions[np.argmax(res)] + '\n')
                    else:
                        sentence.append(actions[np.argmax(res)])
                        with open("detected_actions.txt", "a") as f:
                            f.write(actions[np.argmax(res)] + '\n')

            if len(sentence) > 5: 
                sentence = sentence[-5:]

            # Viz probabilities
            image = prob_viz(res, actions, image, colors)
            
        cv2.rectangle(image, (0,0), (640, 40), (245, 117, 16), -1)
        cv2.putText(image, ' '.join(sentence), (3,30), 
                       cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)
        
        # Show to screen
        cv2.imshow('OpenCV Feed', image)

        # Break gracefully
        if cv2.waitKey(10) & 0xFF == ord('q'):
            break
    cap.release()
    cv2.destroyAllWindows()
# Out:
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 37ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 35ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 33ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 34ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 33ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 36ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 35ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 26ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 28ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 34ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 33ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 37ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 28ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 26ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 38ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 35ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 34ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 35ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 27ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 26ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 36ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 33ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 28ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 27ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 40ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 39ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 40ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 33ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 37ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 38ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 38ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 34ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 37ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 28ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 36ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 33ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 36ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 35ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 34ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 35ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 33ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 28ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 36ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 35ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 33ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 33ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 37ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 37ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 37ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 28ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 27ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 33ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 28ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 34ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 33ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 34ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 34ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 28ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 33ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 39ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 26ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 27ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 28ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 27ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 27ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 33ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 35ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 28ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 37ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 26ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 33ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 37ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 41ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 34ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 33ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 36ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 34ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 27ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 26ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 36ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 27ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 26ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 28ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 28ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 28ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 37ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 28ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 26ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 33ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 34ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 33ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 33ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 35ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 35ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 40ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 36ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 40ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 34ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 33ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 28ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 28ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 27ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 27ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 28ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 26ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 38ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 42ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 34ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 34ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 34ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 34ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 35ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 28ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 34ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 28ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 28ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 33ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 28ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 33ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 34ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 35ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 28ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 33ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 33ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 33ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 33ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 33ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 33ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 35ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 43ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 34ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 27ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 34ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 36ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 27ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 27ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 28ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 28ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 28ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 25ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 28ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 38ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 34ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 34ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 33ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 36ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 33ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 28ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 27ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 28ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 27ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 28ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 26ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 36ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 28ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 33ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 34ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 34ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 34ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 34ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 40ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 41ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 50ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 38ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 40ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 38ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 41ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 41ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 37ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 36ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 39ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 34ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 48ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 39ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 45ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 33ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 37ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 35ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 36ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 40ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 39ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 44ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 36ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 39ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 35ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 38ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 41ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 41ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 37ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 38ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 33ms/step
# No
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 33ms/step
# No

# %%
model.predict(np.expand_dims(X_test[0], axis=0))
# Out:
# 1/1 [==============================] - 0s 134ms/step
# array([[0.18106057, 0.18800765, 0.21044084, 0.19816646, 0.22232449]],
#       dtype=float32)
